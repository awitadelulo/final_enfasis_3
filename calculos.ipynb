# %% [markdown]
# # Datos
# aca lo que se buscara es poder concatenar la informacion de cada evento que se encuentra en los archivos json y tener las tablas de modo que estas puedan ser usadas para calculos futuros

# %%
from extract_data import *
import json
import pandas as pd

# %%
path="data\data\dataSD1500"

# %%
nombres=extract_file_name(path=path)
len(nombres)
# Out:
# 26640

# %%
link=path+"/"+nombres[0]
data=open_file(path=link)
#extract_keys(file=data)

# %%
fdrec=concat_dict(key_name="fdrec",path=path)
fdrec
# Out:
#       id  gpsnanotime  hdSpectrumEye  hdCalibEye  hdXmaxEye  theta  dtheta  \
# 0      1    257161602              0           0          1  48.21    0.38
# 1      4    278779315              0           0          1  46.34    0.45
# 2      1    901642884              0           0          1  27.71    0.74
# 3      1    814732146              0           0          1  45.88    0.40
# 4      4    166608618              0           0          1  23.81    0.42
# ...   ..          ...            ...         ...        ...    ...     ...
# 3185   3    446055306              1           0          1  34.69    0.43
# 3186   3    845250987              0           0          1  28.39    0.40
# 3187   3    913515575              0           0          1  46.31    0.91
# 3188   1    406001797              1           1          1  38.86    0.61
# 3189   2    405994072              1           1          1  38.06    0.38
#
# ...

# %%
sdrec=concat_dict(key_name="sdrec",path=path)
sdrec
# Out:
#        gpsnanotime  theta  dtheta     phi  dphi  energy  denergy       l  \
# 0        226346000  18.89    0.96   33.54  1.01   4.179    0.265  210.91
# 1        972896000  49.25    0.21   85.90  0.31  13.081    0.706  174.65
# 2        638367000  12.44    0.97  106.58  3.55   4.514    0.434   25.88
# 3        238387000  54.83    0.27  335.25  0.31   4.590    0.450  250.82
# 4        902280000  38.05    0.38  320.20  0.77   3.763    0.448  346.11
# ...            ...    ...     ...     ...   ...     ...      ...     ...
# 25081    999674000  76.50    0.10   18.40  0.10   7.479    0.887  196.30
# 25082    535542000  35.88    0.41  143.46  0.84   4.526    0.355  215.52
# 25083    417531000  78.00    0.10   25.60  0.10   7.513    0.945   41.60
# 25084    239178000  41.95    0.28  178.21  0.63   7.237    0.664  295.59
# 25085    438059000  68.30    0.30  145.50  0.30   4.477    0.589   28.20
#
#            b      ra  ...  chi2  ndf  geochi2  geondf  nbstat  \
# ...

# %%
path_2=path="data\data\dataSD750"

# %%
fdrec_path_2=concat_dict(key_name="fdrec",path=path_2)
fdrec_path_2
# Out:
#      id  gpsnanotime  hdSpectrumEye  hdCalibEye  hdXmaxEye  theta  dtheta  \
# 0     6    619754006              0           1          0  32.86    0.78
# 1     6    486303582              0           1          0  25.18    0.31
# 2     6    217795418              0           1          0   2.50    0.70
# 3     6    926661376              0           1          0   6.11    0.61
# 4     6    851359519              0           1          0  26.71    0.30
# ..   ..          ...            ...         ...        ...    ...     ...
# 192   6    701196666              0           1          0  28.24    0.37
# 193   6    735918260              0           1          0  19.42    1.11
# 194   6    736029926              0           1          0  22.75    0.49
# 195   6    512447340              0           1          0  19.87    0.17
# 196   6    165175405              0           1          0  31.56    0.53
#
#         phi   dphi       l  ...  altitude  cherenkovFraction  minViewAngle  \
# ...

# %%
sdrec_path_2=concat_dict(key_name="sdrec",path=path_2)
sdrec_path_2
# Out:
#        gpsnanotime  theta     phi  energy       l      b      ra    dec  \
# 0        650217435  28.51    0.42   0.198  -11.56  13.12  246.41 -30.26
# 1        743559685  18.07  318.30   0.106   -8.57 -21.61  286.70 -45.74
# 2        481967424  33.61  330.65   0.114   -3.93 -39.95  313.40 -44.59
# 3        395818524  20.75    8.62   0.160   14.32 -35.23  309.87 -29.68
# 4        981706229   2.79  241.90   0.136    0.10 -20.10  288.19 -37.58
# ...            ...    ...     ...     ...     ...    ...     ...    ...
# 54476    873550508  39.87  211.14   0.112  -35.34 -70.00    2.48 -45.34
# 54477    696095836  14.80  333.08   0.126 -115.34 -39.38   72.87 -40.62
# 54478    863992520  25.81   92.56   0.297 -153.58 -32.77   70.70  -9.32
# 54479    287317785  22.04   73.54   0.136 -142.52 -22.39   84.52 -13.83
# 54480    114038497  37.34   42.45   0.105 -136.10   5.67  112.98  -7.09
#
#              x     dx  ...  ds450    s35  beta  gamma   chi2  ndf  geochi2  \
# ...
