# %% [markdown]
# Analisis eda de los datos
#
# En el siguiente notebook vamos a tener un pequeño analasis estadiostico sobre los datos fdrec el cual es ingformacion repoliada por detectore de rayos cosmicos, es importante denotar que fdrec tiene la recostruccion de los datos

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fdrec=pd.read_csv("C:/Users/David/OneDrive - Universidad de Medellin/Desktop/final_enfasis_3/fdrec.csv")
fdrec
# Out:
#       id  gpsnanotime  hdSpectrumEye  hdCalibEye  hdXmaxEye  theta  dtheta  \
# 0      1    257161602              0           0          1  48.21    0.38
# 1      4    278779315              0           0          1  46.34    0.45
# 2      1    901642884              0           0          1  27.71    0.74
# 3      1    814732146              0           0          1  45.88    0.40
# 4      4    166608618              0           0          1  23.81    0.42
# ...   ..          ...            ...         ...        ...    ...     ...
# 3382   6    701196666              0           1          0  28.24    0.37
# 3383   6    735918260              0           1          0  19.42    1.11
# 3384   6    736029926              0           1          0  22.75    0.49
# 3385   6    512447340              0           1          0  19.87    0.17
# 3386   6    165175405              0           1          0  31.56    0.53
#
#          phi  dphi       l  ...  altitude  cherenkovFraction  minViewAngle  \
# 0     157.74  0.66  190.73  ...   1389.45               0.08         63.34
# 1     255.79  0.68  300.22  ...   1532.25               0.10         31.97
# 2     349.57  1.31  244.14  ...   1384.84               0.08         47.52
# 3     118.58  0.53  177.78  ...   1391.82               0.11         33.29
# 4      34.96  0.99  233.00  ...   1548.61               0.11         44.82
# ...      ...   ...     ...  ...       ...                ...           ...
# 3382  143.88  0.67  193.35  ...   1557.45               0.05         55.20
# 3383   40.73  2.83  236.75  ...   1581.55               0.10         25.07
# 3384   50.37  1.80  210.73  ...   1580.96               0.11         24.24
# 3385  261.26  2.30  262.54  ...   1581.89               0.12         36.79
# 3386   27.17  0.89  251.35  ...   1545.07               0.13         37.02
#
#         uspL  duspL  uspR  duspR  hottestStationId  distSdpStation  \
# 0     229.80   9.60  0.26   0.05               310           54.05
# 1     220.66   8.71  0.25   0.05               658          130.63
# 2     233.85   8.93  0.25   0.04               246           31.26
# 3     231.96   6.35  0.23   0.04               308          285.74
# 4     232.43  10.05  0.26   0.05               643          599.18
# ...      ...    ...   ...    ...               ...             ...
# 3382  211.07   9.84  0.27   0.05              1825            9.15
# 3383  219.43   7.58  0.26   0.04              1827          316.98
# 3384  211.92  10.75  0.27   0.06              1625          218.02
# 3385  220.00  10.49  0.25   0.05              1829          143.38
# 3386  225.12   9.25  0.25   0.05              1840          122.87
#
#       distAxisStation
# 0              711.71
# 1              163.89
# 2              608.84
# 3              312.06
# 4              599.26
# ...               ...
# 3382            39.79
# 3383           369.34
# 3384           218.09
# 3385           166.04
# 3386           179.87
#
# [3387 rows x 40 columns]

# %%
fdrec[(fdrec["totalEnergy"]>=20) &  (fdrec["totalEnergy"]<=30) ]
# Out:
#       id  gpsnanotime  hdSpectrumEye  hdCalibEye  hdXmaxEye  theta  dtheta  \
# 45     1    879384778              1           0          1  43.41    0.65
# 476    4    514516752              1           0          1  27.95    0.34
# 762    1    942505059              1           1          1  28.35    0.34
# 864    2    500239852              0           0          1  63.17    0.40
# 1090   1    579067207              1           0          1  59.66    0.70
# 1091   4    579042322              1           0          1  59.42    0.65
# 1110   4    531438220              1           1          1  42.94    0.51
# 1133   1    995168201              0           0          1  71.19    0.19
# 1245   2    526006635              1           0          1  49.85    0.54
# 1246   4    526055560              1           0          1  50.07    0.43
# 1538   3    538710889              1           0          1  56.41    0.62
# 1539   4    538674248              1           0          1  56.60    0.50
# 1554   3    212388246              1           1          1  29.36    0.34
# 1609   3    244903839              1           0          1  29.27    0.53
# 1985   1    985218623              1           1          1  45.24    0.19
# 2183   1    552406468              1           1          1  55.79    0.38
# 2266   1    789935913              1           1          1  29.10    0.23
# 2602   3    775389562              0           0          1  68.21    0.24
# 2702   4    933350803              1           0          1  37.62    0.84
# 3031   1    318361132              0           0          1  45.17    0.85
# 3032   3    318388249              0           0          1  45.23    0.39
#
#          phi  dphi       l  ...  altitude  cherenkovFraction  minViewAngle  \
# 45    349.96  0.99  260.44  ...   1379.96               0.13         34.85
# 476    49.27  0.42  358.97  ...   1489.16               0.06         58.17
# 762   108.85  0.37  359.25  ...   1378.74               0.06         59.51
# 864   121.95  0.73  125.37  ...   1390.89               0.14         25.87
# 1090   38.03  0.54  212.58  ...   1432.57               0.14         25.43
# 1091   37.30  0.96  213.29  ...   1432.55               0.08         44.50
# 1110  125.27  1.04  149.72  ...   1404.33               0.06        106.63
# 1133  257.25  0.45  319.71  ...   1362.97               0.03         99.83
# 1245   11.44  0.71   48.68  ...   1400.81               0.06         89.80
# 1246    9.63  1.23   47.80  ...   1400.80               0.13         25.43
# 1538  136.38  0.79    1.18  ...   1418.77               0.07         72.84
# 1539  135.99  0.99    1.89  ...   1418.77               0.06         92.35
# 1554  263.06  1.71  322.68  ...   1407.51               0.09         40.86
# 1609   87.13  0.56   42.16  ...   1512.64               0.07         78.51
# 1985  201.37  0.32  263.68  ...   1404.29               0.08         73.54
# 2183  103.62  0.89  136.63  ...   1522.14               0.25         19.80
# 2266   20.98  1.33  329.74  ...   1381.14               0.10         37.92
# 2602    6.59  0.53   61.44  ...   1579.82               0.04        103.05
# 2702   88.36  1.10   73.83  ...   1417.82               0.06         89.24
# 3031  221.51  1.11  295.47  ...   1460.32               0.07        102.41
# 3032  222.80  1.43  295.56  ...   1460.33               0.11         31.06
#
#         uspL  duspL  uspR  duspR  hottestStationId  distSdpStation  \
# 45    241.82   8.65  0.22   0.04               278          342.94
# 476   255.89   8.57  0.29   0.03               588          943.75
# 762   225.69   5.71  0.24   0.04               357          453.25
# 864   236.91   4.73  0.26   0.03               413         1346.89
# 1090  244.97   6.66  0.20   0.04              1306          544.35
# 1091  243.91   6.18  0.25   0.04              1306          466.54
# 1110  237.34   8.49  0.26   0.04               825           58.94
# 1133  236.02   6.78  0.24   0.05              1477          405.51
# 1245  235.55   6.78  0.25   0.05              1362          321.77
# 1246  233.74   7.68  0.22   0.04              1362          487.10
# 1538  236.22   8.32  0.27   0.05               843          430.16
# 1539  243.96   6.02  0.29   0.05               843          107.82
# 1554  231.96   8.42  0.31   0.04               846           50.83
# 1609  223.15   7.99  0.25   0.05               979          417.57
# 1985  228.21   4.51  0.23   0.05               448          466.52
# 2183  249.07   5.86  0.27   0.04              1055          413.72
# 2266  232.35   7.35  0.26   0.03               280          516.16
# 2602  236.09   6.41  0.28   0.04               605           64.83
# 2702  232.20   7.60  0.23   0.04               487          418.68
# 3031  234.48   9.52  0.26   0.05              1729          383.04
# 3032  238.23   7.00  0.22   0.04              1729          573.34
#
#       distAxisStation
# 45             348.75
# 476            947.24
# 762            588.54
# 864           1357.94
# 1090           547.51
# 1091           492.43
# 1110           536.84
# 1133           419.58
# 1245           657.73
# 1246           488.60
# 1538           776.77
# 1539           682.55
# 1554           368.73
# 1609           480.52
# 1985           645.00
# 2183           513.79
# 2266           594.64
# 2602           459.67
# 2702           463.11
# 3031           496.14
# 3032           575.86
#
# [21 rows x 40 columns]

# %%
#tipos de datos que tiene cada columna
fdrec.dtypes
# Out:
# id                     int64
# gpsnanotime            int64
# hdSpectrumEye          int64
# hdCalibEye             int64
# hdXmaxEye              int64
# theta                float64
# dtheta               float64
# phi                  float64
# dphi                 float64
# l                    float64
# b                    float64
# ra                   float64
# dec                  float64
# totalEnergy          float64
# dtotalEnergy         float64
# calEnergy            float64
# dcalEnergy           float64
# xmax                 float64
# dxmax                float64
# heightXmax           float64
# distXmax             float64
# dEdXmax              float64
# ddEdXmax             float64
# x                    float64
# dx                   float64
# y                    float64
# dy                   float64
# z                    float64
# easting              float64
# northing             float64
# altitude             float64
# cherenkovFraction    float64
# minViewAngle         float64
# uspL                 float64
# duspL                float64
# uspR                 float64
# duspR                float64
# hottestStationId       int64
# distSdpStation       float64
# distAxisStation      float64
# dtype: object

# %%
def histogramas(columns, df,nombre,x=False):
    for col in columns:
        if pd.api.types.is_numeric_dtype(df[col]):
            sd = np.std(fdrec[col])
            mn = np.mean(fdrec[col])
            plt.figure(figsize=(10, 6))
            
            plt.hist(df[col].dropna(), bins=20, edgecolor='black', color='#81d4fa')
            if x == True:
                plt.axvline(mn + sd, color='#f08080', linestyle='--', label=f'1 Desv. Est.{round((mn + sd),2)}')
                plt.axvline(mn - sd, color='#f08080', linestyle='--', label=f'- 1 Desv. Est.{round((mn - sd),2)}')
                plt.axvline(mn - 2*sd, color='#a5d6a7', linestyle='--', label=f'- 2 Desv. Est.{round((mn - 2*sd),2)}')
                plt.axvline(mn + 2*sd, color='#a5d6a7', linestyle='--', label=f'+ 2 Desv. Est.{round((mn + 2*sd),2)}')
                plt.axvline(mn, color='green', linestyle='-', label=f'Media {round(mn,2)}')


            plt.xlabel(col)
            plt.ylabel('Frecuency')
            plt.legend()
            plt.savefig(f"../images/{nombre}.png")
            plt.show()
            
        else:
            print(f"La columna '{col}' no es numérica y se omite.")

# %%
#"xmax","dxmax"
histogramas(columns=["xmax"],df=fdrec,nombre="xmaxhist",x=False)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
histogramas(columns=["totalEnergy","calEnergy "],df=fdrec)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
histogramas(columns=["dtotalEnergy","dcalEnergy"],df=fdrec)

# %%
histogramas(columns=["xmax","dxmax"],df=fdrec)

# %%
#distribuciones
def mapa_correlacion(df):
    # Calcular la matriz de correlación
    correlacion = df.corr(numeric_only=True)

    # Crear el mapa de calor
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlacion, annot=True, cmap='coolwarm', center=0, fmt=".2f")
    plt.title('Matriz de Correlación')
    plt.tight_layout()
    plt.savefig("../images/heathist.png")
    plt.show()

# %%
mapa_correlacion(fdrec[["theta","phi","dec","totalEnergy","dtotalEnergy","calEnergy","dcalEnergy","xmax"
                        ,"heightXmax","dEdXmax"]])

# %%
# Agregar 
import pandas as pd
import numpy as np
import random
# Supongamos que tienes un DataFrame con una columna 'Xmax'
# df = pd.read_csv("tus_datos.csv")

# Ejemplo de generación de muestra aleatoria si aún no tienes el archivo:
# df = pd.DataFrame({'Xmax': np.random.uniform(680, 1050, 1000)})

def assign_particle(xmax):
    # Definimos las probabilidades basadas en rangos
    random.seed(2)
    if xmax < 720:
        prob_proton = 0.01
    elif xmax < 740:
        prob_proton = 0.05
    elif xmax < 760:
        prob_proton = 0.15
    elif xmax < 780:
        prob_proton = 0.30
    elif xmax < 800:
        prob_proton = 0.50
    elif xmax < 820:
        prob_proton = 0.70
    elif xmax < 840:
        prob_proton = 0.85
    elif xmax < 880:
        prob_proton = 0.95
    else:
        prob_proton = 0.99
    
    # Asignamos clase basada en una tirada aleatoria
    return 'proton' if np.random.rand() < prob_proton else 'iron'

# Asignar nueva columna
fdrec_particle  = fdrec.copy()
fdrec_particle["particle_type"] = fdrec_particle["xmax"].apply(assign_particle)

# Opcional: guardar nuevo archivo
# df.to_csv("datos_clasificados.csv", index=False)

# %%
sns.histplot(fdrec_particle, x="xmax",hue="particle_type")
plt.savefig("../images/typeparticlehist.png")

# %%
fdrec_particle["particle_type"].value_counts()
# Out:
# particle_type
# iron      2725
# proton     662
# Name: count, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pandas as pd

def modelo_arbol_decision(df, target_col='particle_type', max_depth=3, test_size=0.3, random_state=42):


    # Verificar si el target existe
    if target_col not in df.columns:
        raise ValueError(f"La columna objetivo '{target_col}' no está en el DataFrame.")

    # Separar características (X) y etiquetas (y)
    y = df[target_col].astype(str)
    X = df.drop(columns=[target_col])

    # Dividir los datos
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state
    )

    # Modelo
    model = DecisionTreeClassifier(max_depth=max_depth, random_state=random_state)
    model.fit(X_train, y_train)

    # Predicciones
    y_pred = model.predict(X_test)

    # Reporte
    report = classification_report(y_test, y_pred)

    # DataFrame de resultados
    resultado_df = X_test.copy()
    resultado_df['true_label'] = y_test.values
    resultado_df['predicted'] = y_pred

    return model, report, resultado_df

# %%
model=fdrec_particle[["theta","phi","dec","totalEnergy","dtotalEnergy","calEnergy","dcalEnergy","xmax"
                        ,"heightXmax","dEdXmax","particle_type"]]
modelo, reporte, resultado_df=modelo_arbol_decision(df=model, max_depth=3, test_size=0.20, random_state=42)

# %%
modelo
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
print(reporte)
# Out:
#               precision    recall  f1-score   support
#
#         iron       0.91      0.95      0.93       548
#       proton       0.73      0.61      0.66       130
#
#     accuracy                           0.88       678
#    macro avg       0.82      0.78      0.80       678
# weighted avg       0.88      0.88      0.88       678

# %%
resultado_df["true_label"].value_counts()

newdf = resultado_df[resultado_df["true_label"]=="proton"]

# %%
a = newdf ["true_label"]==newdf ["predicted"]
a.value_counts()
# Out:
# True     79
# False    51
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(resultado_df["true_label"], resultado_df["predicted"])
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8820
